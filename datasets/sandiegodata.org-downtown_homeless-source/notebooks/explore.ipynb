# %%
import seaborn as sns
import metapack as mp
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display 

# %matplotlib inline
sns.set_context('notebook')
mp.jupyter.init()

# %%
pkg = mp.jupyter.open_package()
#pkg = mp.jupyter.open_source_package()
pkg
# Out:
# # Downtown Homelessness Source Package
# `sandiegodata.org-downtown_homeless-source-6` Last Update: 2019-10-01T21:02:19
#
# _Source files for San Diego Downtown homeless sleeper counts_
#
#
# This dataset provides geographic locations for homeless sleepers in Downtown San Diego, as counted by enumerators from the Downtown San Diego Partnership. These counts have been done monthly since 2012, and this dataset provides counts since 2014.
#
# This is the source package, use to generate analysis packages. Analysts should probably use one of the analysis packages. See the [Data Library's Homelessness Collection](https://data.sandiegodata.org/collections/homelessness/) for all of the available datasets.
#
# The count is done on paper maps with handwritten count marks. The San Diego
# Regional Data Library's [Downton Homelessness
# project](http://downtown-homelessness.sandiegodata.org/) converted these
# scanned count maps using a [web based image annotation
# ...

# %%
pkg.resource('files')
# Out:
# <Resource: metadata.csv 28:1 root.datafile data/files.csv ['files', 'Final file annotations, including total counts, temperature and weather.', '', '']>

# %%
counts = pkg.resource('counts').dataframe()
counts.neighborhood.replace({'':'gaslamp'}).unique()
counts.head()
# Out:
#                                     file_id neighborhood       date  count  \
# 0  1+VNSWKPSeaP9tCNcDBttFERz5ShCwWDB3nFdA==      gaslamp 2018-01-24      1
# 1  1+VNSWKPSeaP9tCNcDBttFERz5ShCwWDB3nFdA==      gaslamp 2018-01-24      2
# 2  1+VNSWKPSeaP9tCNcDBttFERz5ShCwWDB3nFdA==      gaslamp 2018-01-24      2
# 3  1+VNSWKPSeaP9tCNcDBttFERz5ShCwWDB3nFdA==      gaslamp 2018-01-24      2
# 4  1+VNSWKPSeaP9tCNcDBttFERz5ShCwWDB3nFdA==      gaslamp 2018-01-24      2
#
#          type             x             y
# 0  Individual  6.281628e+06  1.841306e+06
# 1  Individual  6.281782e+06  1.841132e+06
# 2  Individual  6.281640e+06  1.841133e+06
# 3  Individual  6.281563e+06  1.840941e+06
# 4  Individual  6.281498e+06  1.840795e+06

# %%
files = pkg.resource('files').dataframe()
files.head().T
# Out:
#                                                                   0  \
# image_url         http://ds.civicknowledge.org/downtownsandiego....
# file_id                    1+VNSWKPSeaP9tCNcDBttFERz5ShCwWDB3nFdA==
# source_file       /Users/eric/Google Sync/sandiegodata.org/Proje...
# url_year                                                       2018
# url_month                                                         1
# date                                            2018-01-24 00:00:00
# neighborhood                                                gaslamp
# url_neighborhood                                            gaslamp
# total_count                                                    44.0
# temp                                                             52
# rain                                                          clear
#
#                                                                   1  \
# image_url         http://ds.civicknowledge.org/downtownsandiego....
# ...

# %%
t = files[['file_id','image_url','url_year','url_month', 'url_neighborhood']].merge(counts[['file_id','date']], on='file_id')
t = t[['image_url','url_year','url_month', 'date', 'url_neighborhood']].drop_duplicates()
t.head()
# Out:
#                                              image_url  url_year  url_month  \
# 0    http://ds.civicknowledge.org/downtownsandiego....      2018          1
# 25   http://ds.civicknowledge.org/downtownsandiego....      2018          2
# 57   http://ds.civicknowledge.org/downtownsandiego....      2018          3
# 93   http://ds.civicknowledge.org/downtownsandiego....      2018          4
# 119  http://ds.civicknowledge.org/downtownsandiego....      2018          5
#
#           date url_neighborhood
# 0   2018-01-24          gaslamp
# 25  2018-02-21          gaslamp
# 57  2018-03-28          gaslamp
# 93  2018-04-25          gaslamp
# 119 2018-05-31          gaslamp

# %%
len(counts)
# Out:
# 11574
