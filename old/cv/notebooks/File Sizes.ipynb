# %%
from IPython.display import Image as ImageDisp
from pathlib import Path
import pandas as pd

# %%
p = Path('../images/')

# %%
a = []
for f in p.glob('**/*.png'):
    sz = f.stat().st_size
    a.append(sz)
    print(f.stat().st_size, f)
# Out:
# 60692 ../images/2014/03/201403-000.png
# 7579 ../images/2014/03/201403-001.png
# 1266296 ../images/2014/03/201403-003.png
# 1270028 ../images/2014/03/201403-002.png
# 847193 ../images/2014/03/201403-006.png
# 549923 ../images/2014/03/201403-005.png
# 816099 ../images/2014/03/201403-004.png
# 145074 ../images/2014/04/201404-002.png
# 186420 ../images/2014/04/201404-003.png
# 7579 ../images/2014/04/201404-001.png
# 55886 ../images/2014/04/201404-000.png
# 107833 ../images/2014/04/201404-004.png
# 113130 ../images/2014/04/201404-005.png
# 72597 ../images/2014/04/201404-006.png
# 778015 ../images/2014/05/201405-006.png
# 467164 ../images/2014/05/201405-004.png
# 1174709 ../images/2014/05/201405-005.png
# 7579 ../images/2014/05/201405-001.png
# 60692 ../images/2014/05/201405-000.png
# 1163553 ../images/2014/05/201405-002.png
# 732383 ../images/2014/05/201405-003.png
# 831378 ../images/2014/02/201402-005.png
# 994769 ../images/2014/02/201402-004.png
# ...

# %%
#ImageDisp('../images/2014/11/201411-006.png')

df = pg.DataFrame()
