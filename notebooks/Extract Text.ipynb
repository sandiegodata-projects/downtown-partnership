# %%
from IPython.display import Image as ImageDisp
# import the necessary packages
from PIL import Image
import pytesseract
import argparse
import cv2
import os
import pathlib

# %%
ImageDisp('../images/2014/01/201401-marina.png')

# %%
from sklearn.cluster import KMeans

if False:

    # load the example image and convert it to grayscale
    image = cv2.imread('../images/2014/01/201401-002.png')
    img = image.reshape((image.shape[0] * image.shape[1],3))

    clt = KMeans(n_clusters=4) #cluster number
    clt.fit(img)

    numLabels = np.arange(0, len(np.unique(clt.labels_)) + 1)
    (hist, _) = np.histogram(clt.labels_, bins=numLabels)

    hist = hist.astype("float")
    hist /= hist.sum()

    list(reversed(sorted(zip(clt.cluster_centers_, hist), key = lambda e: e[1])))

# %%
image = cv2.imread('../images/2014/01/201401-002.png')

# %%
for f in pathlib.Path('../images/2014').glob('**/*.png'):
    img = cv2.imread(str(f))
    
    
        
    print(str(f))
# Out:
# ../images/2014/03/201403-003.png
# ../images/2014/03/201403-002.png
# ../images/2014/03/201403-006.png
# ../images/2014/03/201403-005.png
# ../images/2014/03/201403-004.png
# ../images/2014/04/201404-002.png
# ../images/2014/04/201404-003.png
# ../images/2014/04/201404-004.png
# ../images/2014/04/201404-005.png
# ../images/2014/04/201404-006.png
# ../images/2014/05/201405-006.png
# ../images/2014/05/201405-004.png
# ../images/2014/05/201405-005.png
# ../images/2014/05/201405-002.png
# ../images/2014/05/201405-003.png
# ../images/2014/02/201402-005.png
# ../images/2014/02/201402-004.png
# ../images/2014/02/201402-006.png
# ../images/2014/02/201402-003.png
# ../images/2014/02/201402-002.png
# ../images/2014/11/201411-006.png
# ../images/2014/11/201411-005.png
# ../images/2014/11/201411-004.png
# ../images/2014/11/201411-003.png
# ../images/2014/11/201411-002.png
# ../images/2014/10/201410-003.png
# ../images/2014/10/201410-002.png
# ../images/2014/10/201410-005.png
# ...
