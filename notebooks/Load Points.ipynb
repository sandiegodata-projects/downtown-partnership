# %%
# Out:
#                                             filename  \
# 0  /Users/eric/Google Sync/sandiegodata.org/Proje...
# 1  /Users/eric/Google Sync/sandiegodata.org/Proje...
# 2  /Users/eric/Google Sync/sandiegodata.org/Proje...
# 3  /Users/eric/Google Sync/sandiegodata.org/Proje...
# 4  /Users/eric/Google Sync/sandiegodata.org/Proje...
#
#                                                  url    cx   cy     r  \
# 0  http://ds.civicknowledge.org/downtownsandiego....   386  730  22.0
# 1  http://ds.civicknowledge.org/downtownsandiego....   547  826  22.0
# 2  http://ds.civicknowledge.org/downtownsandiego....   971  837  23.0
# 3  http://ds.civicknowledge.org/downtownsandiego....   615  905  25.0
# 4  http://ds.civicknowledge.org/downtownsandiego....  1347  939  21.0
#
#          type count
# 0  Individual
# 1  Individual     2
# 2  Individual     2
# 3  Individual
# 4  Individual

# %%
file_df.head().T
# Out:
#                                                                 0  \
# filename        /Users/eric/Google Sync/sandiegodata.org/Proje...
# url             http://ds.civicknowledge.org/downtownsandiego....
# date                                                    2017-1-26
# neighborhood_x                                             Marina
# total_count                                                    26
# temp                                                           42
# rain                                                        clear
# neighborhood_y                                             marina
# source          POLYGON ((548 1037, 545 1160, 1637 1171, 1636 ...
# dest            POLYGON ((6281151 1840266.99999984, 6278933 18...
# matrix          [[-0.8453435071536253, -0.539733097445903, 0.0...
# tf              [[-0.8453435071536253, -0.539733097445903, 0.0...
#
#                                                                 1  \
# ...

# %%
tf
# Out:
#                                                   url  neighborhood  \
# 0   http://ds.civicknowledge.org/downtownsandiego....        cortez
# 1   http://ds.civicknowledge.org/downtownsandiego....        cortez
# 2   http://ds.civicknowledge.org/downtownsandiego....        cortez
# 3   http://ds.civicknowledge.org/downtownsandiego....        cortez
# 4   http://ds.civicknowledge.org/downtownsandiego....        cortez
# 5   http://ds.civicknowledge.org/downtownsandiego....        cortez
# 6   http://ds.civicknowledge.org/downtownsandiego....  east_village
# 7   http://ds.civicknowledge.org/downtownsandiego....  east_village
# 8   http://ds.civicknowledge.org/downtownsandiego....       gaslamp
# 9   http://ds.civicknowledge.org/downtownsandiego....       gaslamp
# 10  http://ds.civicknowledge.org/downtownsandiego....       gaslamp
# 11  http://ds.civicknowledge.org/downtownsandiego....       gaslamp
# 12  http://ds.civicknowledge.org/downtownsandiego....       gaslamp
# ...
